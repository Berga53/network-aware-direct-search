# %% [markdown]
# # NaDS: Network-aware Direct Search
#
# Driver notebook for the `nads` package in `src/`. All algorithms live in the
# package; this notebook only calls them and summarises the published results in
# `results/`. Across the code and the result files, `NS` stands for NaDS.
#
# 1. A quick live demo on a small synthetic graph.
# 2. Summaries of the paper's results: final spread from single-discount seeds, and convergence from random starts.
#
# To regenerate the full experiments, use the scripts in `scripts/` (see the README).

# %%
import contextlib
import io
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sys.path.insert(0, str(Path("src").resolve()))

from nads import (
    CDS_solver,
    DEFAULT_PARAMS,
    NS_solver,
    Influence_evaluation,
    SingleDiscount,
    create_graph,
    greedy,
    set_seeds,
)

set_seeds()

# %% [markdown]
# ## 1. Live demo
#
# Two-block stochastic block model, seed-set size `K = 3`, and a 5-second budget for each direct-search solver
# started from the single-discount seeds.

# %%
params = DEFAULT_PARAMS          # (l0, h0, theta_l, theta_h, gamma, eps)
delta, xi, d, buffer_dim = 0.5, 0.1, 2, 500
K, max_time = 3, 5

g, W, A = create_graph(size=[50, 50], probs=[[0.9, 0.1], [0.1, 0.9]], weights=0.1)

s_disc, x0 = SingleDiscount(g, W, params, K)
s_greedy, _ = greedy(g, W, params, K)
with contextlib.redirect_stdout(io.StringIO()):   # the solvers print a progress line per evaluation
    s_ns, _, hist_ns = NS_solver(g, W, x0, params, delta, xi, d, max_time, buffer_dim)
    s_cds, _, hist_cds = CDS_solver(g, W, x0, params, delta, xi, d, max_time, buffer_dim)

pd.Series(
    {"single discount": s_disc, "greedy": s_greedy, "CDS": s_cds[-1], "NS (NaDS)": s_ns[-1]},
    name="influence spread",
).to_frame()

# %% [markdown]
# ## 2. Published results
#
# `results/<network>/` holds the files behind the paper's figures and tables:
#
# - `ns_cds_disc/{ns,cds}_disc_<K>.csv`: solver history from the single-discount seeds. Columns are `spread, elapsed seconds, influence evaluations`.
# - `ns_cds_random/{ns,cds}_<K>.csv`: best spread found at each second (columns) for each of 10 random starts (rows).
# - `scores.csv`, `times.csv`: baseline scores and running times, one row per method and one column per `K` in `5, 10, 15, 20`.
#
# (Two networks also have `- Copia.csv` variants of `scores` and `times`, and two have a `greed.csv` with the greedy results.)

# %%
RESULTS = Path("results")
K_LIST = [5, 10, 15, 20]

rows = []
for net in sorted(p.name for p in RESULTS.iterdir() if p.is_dir()):
    row = {"network": net}
    for K in K_LIST:
        for solver in ("ns", "cds"):
            hist = np.loadtxt(RESULTS / net / "ns_cds_disc" / f"{solver}_disc_{K}.csv", ndmin=2)
            row[f"{solver.upper()} K={K}"] = hist[-1, 0]
    rows.append(row)

pd.DataFrame(rows).set_index("network").round(1)

# %%
def curve_stats(path):
    runs = np.loadtxt(path, ndmin=2)
    return np.median(runs, axis=0), np.mean(runs, axis=0), np.std(runs, axis=0)


network = "Facebook"
fig, axes = plt.subplots(1, len(K_LIST), figsize=(4 * len(K_LIST), 3), sharey=False)
for ax, K in zip(axes, K_LIST):
    for solver, color in (("cds", "tab:orange"), ("ns", "tab:blue")):
        median, mean, std = curve_stats(RESULTS / network / "ns_cds_random" / f"{solver}_{K}.csv")
        t = np.arange(len(mean))
        ax.plot(t, median, color=color, label=solver.upper() if solver == "cds" else "NS (NaDS)")
        ax.fill_between(t, mean - std, mean + std, color=color, alpha=0.2)
    ax.set_title(f"{network}, K={K}")
    ax.set_xlabel("time (s)")
axes[0].set_ylabel("influence spread")
axes[0].legend()
fig.tight_layout()
